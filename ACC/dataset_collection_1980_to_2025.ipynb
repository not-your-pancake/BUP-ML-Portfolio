# %%
import requests
import pandas as pd
from datetime import datetime
import time
import os

API_KEY = "7FSTWLFXDXYPT4LJ69H2SARW9"

DISTRICTS = [
    "Bagerhat,Bangladesh", "Bandarban,Bangladesh", "Barguna,Bangladesh", "Barisal,Bangladesh", "Bhola,Bangladesh",
    "Bogra,Bangladesh", "Brahmanbaria,Bangladesh", "Chandpur,Bangladesh", "Chittagong,Bangladesh", "Chuadanga,Bangladesh",
    "Comilla,Bangladesh", "Cox's Bazar,Bangladesh", "Dhaka,Bangladesh", "Dinajpur,Bangladesh", "Faridpur,Bangladesh",
    "Feni,Bangladesh", "Gaibandha,Bangladesh", "Gazipur,Bangladesh", "Gopalganj,Bangladesh", "Habiganj,Bangladesh",
    "Jamalpur,Bangladesh", "Jessore,Bangladesh", "Jhalokati,Bangladesh", "Jhenaidah,Bangladesh", "Joypurhat,Bangladesh",
    "Khagrachhari,Bangladesh", "Khulna,Bangladesh", "Kishoreganj,Bangladesh", "Kurigram,Bangladesh", "Kushtia,Bangladesh",
    "Lakshmipur,Bangladesh", "Lalmonirhat,Bangladesh", "Madaripur,Bangladesh", "Magura,Bangladesh", "Manikganj,Bangladesh",
    "Meherpur,Bangladesh", "Moulvibazar,Bangladesh", "Munshiganj,Bangladesh", "Mymensingh,Bangladesh", "Naogaon,Bangladesh",
    "Narail,Bangladesh", "Narayanganj,Bangladesh", "Narsingdi,Bangladesh", "Natore,Bangladesh", "Nawabganj,Bangladesh",
    "Netrakona,Bangladesh", "Nilphamari,Bangladesh", "Noakhali,Bangladesh", "Pabna,Bangladesh", "Panchagarh,Bangladesh",
    "Patuakhali,Bangladesh", "Pirojpur,Bangladesh", "Rajbari,Bangladesh", "Rajshahi,Bangladesh", "Rangamati,Bangladesh",
    "Rangpur,Bangladesh", "Satkhira,Bangladesh", "Shariatpur,Bangladesh", "Sherpur,Bangladesh", "Sirajganj,Bangladesh",
    "Sunamganj,Bangladesh", "Sylhet,Bangladesh", "Tangail,Bangladesh", "Thakurgaon,Bangladesh"
]

START_YEAR = 2023
END_YEAR = 2025

def fetch_weather_year(location, year):
    start_date = f"{year}-03-01"
    end_date = f"{year}-11-20"
    
    # CRITICAL: Elements parameter added to fetch AQI and PM data
    elements = "datetime,temp,humidity,pressure,uvindex,aqius,aqieur,pm1,pm2p5,pm10,so2,no2,o3,co"
    url = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{location}/{start_date}/{end_date}?unitGroup=metric&elements={elements}&include=days&key={API_KEY}&contentType=json"
    
    try:
        response = requests.get(url, timeout=15)
        response.raise_for_status()
        data = response.json()
        return data.get("days", [])
    except Exception as e:
        print(f"Error for {location} {year}: {str(e)}")
        return []

for location in DISTRICTS:
    district_clean = location.split(',')[0]
    filename = f"{district_clean}_historical_weather_2023_to_2025.csv"
    
    if os.path.exists(filename):
        print(f"Skipping {district_clean}, file exists.")
        continue

    print(f"\nProcessing: {district_clean}")
    extracted_data = []
    
    for year in range(START_YEAR, END_YEAR + 1):
        days_data = fetch_weather_year(location, year)
        
        for day in days_data:
            date_str = day.get("datetime")
            if date_str:
                dt = datetime.strptime(date_str, "%Y-%m-%d")
                
                row = {
                    "district": district_clean,
                    "date": date_str,
                    "year": dt.year,
                    "month": dt.month,
                    "day": dt.day,
                    "temp": day.get("temp"),
                    "humidity": day.get("humidity"),
                    "pressure": day.get("pressure"),
                    "uv_index": day.get("uvindex"),
                    "aqi_us": day.get("aqius"),
                    "aqi_eu": day.get("aqieur"),
                    "pm1": day.get("pm1"),
                    "pm2_5": day.get("pm2p5"), # Note: API returns 'pm2p5'
                    "pm10": day.get("pm10"),
                    "so2_ppb": day.get("so2"),
                    "no2_ppb": day.get("no2"),
                    "o3_ppb": day.get("o3"),
                    "co_ppb": day.get("co")
                }
                extracted_data.append(row)
        
        time.sleep(1) # Short sleep to be polite to the API

    if extracted_data:
        df = pd.DataFrame(extracted_data)
        df.to_csv(filename, index=False)
        print(f"Saved {len(df)} records to {filename}")
# Out:
# Processing: Bagerhat
# Saved 795 records to Bagerhat_historical_weather_2023_to_2025.csv
#
# Processing: Bandarban
# Saved 795 records to Bandarban_historical_weather_2023_to_2025.csv
#
# Processing: Barguna
# Saved 795 records to Barguna_historical_weather_2023_to_2025.csv
#
# Processing: Barisal
# Saved 795 records to Barisal_historical_weather_2023_to_2025.csv
#
# Processing: Bhola
# Saved 795 records to Bhola_historical_weather_2023_to_2025.csv
#
# Processing: Bogra
# Saved 795 records to Bogra_historical_weather_2023_to_2025.csv
#
# Processing: Brahmanbaria
# Saved 795 records to Brahmanbaria_historical_weather_2023_to_2025.csv
#
# Processing: Chandpur
# Saved 795 records to Chandpur_historical_weather_2023_to_2025.csv
#
# Processing: Chittagong
# Saved 795 records to Chittagong_historical_weather_2023_to_2025.csv
#
# Processing: Chuadanga
# Saved 795 records to Chuadanga_historical_weather_2023_to_2025.csv
#
# Processing: Comilla
# Saved 795 records to Comilla_historical_weather_2023_to_2025.csv
#
# Processing: Cox's Bazar
# Saved 795 records to Cox's Bazar_historical_weather_2023_to_2025.csv
#
# Processing: Dhaka
# Saved 795 records to Dhaka_historical_weather_2023_to_2025.csv
#
# Processing: Dinajpur
# Saved 795 records to Dinajpur_historical_weather_2023_to_2025.csv
#
# Processing: Faridpur
# Saved 795 records to Faridpur_historical_weather_2023_to_2025.csv
#
# Processing: Feni
# Saved 795 records to Feni_historical_weather_2023_to_2025.csv
#
# Processing: Gaibandha
# Saved 795 records to Gaibandha_historical_weather_2023_to_2025.csv
#
# Processing: Gazipur
# Saved 795 records to Gazipur_historical_weather_2023_to_2025.csv
#
# Processing: Gopalganj
# Saved 795 records to Gopalganj_historical_weather_2023_to_2025.csv
#
# Processing: Habiganj
# Saved 795 records to Habiganj_historical_weather_2023_to_2025.csv
#
# Processing: Jamalpur
# Saved 795 records to Jamalpur_historical_weather_2023_to_2025.csv
#
# Processing: Jessore
# Saved 795 records to Jessore_historical_weather_2023_to_2025.csv
#
# Processing: Jhalokati
# Saved 795 records to Jhalokati_historical_weather_2023_to_2025.csv
#
# Processing: Jhenaidah
# Saved 795 records to Jhenaidah_historical_weather_2023_to_2025.csv
#
# Processing: Joypurhat
# Saved 795 records to Joypurhat_historical_weather_2023_to_2025.csv
#
# Processing: Khagrachhari
# Saved 795 records to Khagrachhari_historical_weather_2023_to_2025.csv
#
# Processing: Khulna
# Saved 795 records to Khulna_historical_weather_2023_to_2025.csv
#
# Processing: Kishoreganj
# Saved 795 records to Kishoreganj_historical_weather_2023_to_2025.csv
#
# Processing: Kurigram
# Saved 795 records to Kurigram_historical_weather_2023_to_2025.csv
#
# Processing: Kushtia
# Saved 795 records to Kushtia_historical_weather_2023_to_2025.csv
#
# Processing: Lakshmipur
# Saved 795 records to Lakshmipur_historical_weather_2023_to_2025.csv
#
# Processing: Lalmonirhat
# Saved 795 records to Lalmonirhat_historical_weather_2023_to_2025.csv
#
# Processing: Madaripur
# Saved 795 records to Madaripur_historical_weather_2023_to_2025.csv
#
# Processing: Magura
# Saved 795 records to Magura_historical_weather_2023_to_2025.csv
#
# Processing: Manikganj
# Saved 795 records to Manikganj_historical_weather_2023_to_2025.csv
#
# Processing: Meherpur
# Saved 795 records to Meherpur_historical_weather_2023_to_2025.csv
#
# Processing: Moulvibazar
# Saved 795 records to Moulvibazar_historical_weather_2023_to_2025.csv
#
# Processing: Munshiganj
# Saved 795 records to Munshiganj_historical_weather_2023_to_2025.csv
#
# Processing: Mymensingh
# Saved 795 records to Mymensingh_historical_weather_2023_to_2025.csv
#
# Processing: Naogaon
# Saved 795 records to Naogaon_historical_weather_2023_to_2025.csv
#
# Processing: Narail
# Saved 795 records to Narail_historical_weather_2023_to_2025.csv
#
# Processing: Narayanganj
# Saved 795 records to Narayanganj_historical_weather_2023_to_2025.csv
#
# Processing: Narsingdi
# Saved 795 records to Narsingdi_historical_weather_2023_to_2025.csv
#
# Processing: Natore
# Saved 795 records to Natore_historical_weather_2023_to_2025.csv
#
# Processing: Nawabganj
# Saved 795 records to Nawabganj_historical_weather_2023_to_2025.csv
#
# Processing: Netrakona
# Saved 795 records to Netrakona_historical_weather_2023_to_2025.csv
#
# Processing: Nilphamari
# Saved 795 records to Nilphamari_historical_weather_2023_to_2025.csv
#
# Processing: Noakhali
# Saved 795 records to Noakhali_historical_weather_2023_to_2025.csv
#
# Processing: Pabna
# Saved 795 records to Pabna_historical_weather_2023_to_2025.csv
#
# Processing: Panchagarh
# Saved 795 records to Panchagarh_historical_weather_2023_to_2025.csv
#
# Processing: Patuakhali
# Saved 795 records to Patuakhali_historical_weather_2023_to_2025.csv
#
# Processing: Pirojpur
# Saved 795 records to Pirojpur_historical_weather_2023_to_2025.csv
#
# Processing: Rajbari
# Saved 795 records to Rajbari_historical_weather_2023_to_2025.csv
#
# Processing: Rajshahi
# Saved 795 records to Rajshahi_historical_weather_2023_to_2025.csv
#
# Processing: Rangamati
# Saved 795 records to Rangamati_historical_weather_2023_to_2025.csv
#
# Processing: Rangpur
# Saved 795 records to Rangpur_historical_weather_2023_to_2025.csv
#
# Processing: Satkhira
# Saved 795 records to Satkhira_historical_weather_2023_to_2025.csv
#
# Processing: Shariatpur
# Saved 795 records to Shariatpur_historical_weather_2023_to_2025.csv
#
# Processing: Sherpur
# Saved 795 records to Sherpur_historical_weather_2023_to_2025.csv
#
# Processing: Sirajganj
# Saved 795 records to Sirajganj_historical_weather_2023_to_2025.csv
#
# Processing: Sunamganj
# Saved 795 records to Sunamganj_historical_weather_2023_to_2025.csv
#
# Processing: Sylhet
# Saved 795 records to Sylhet_historical_weather_2023_to_2025.csv
#
# Processing: Tangail
# Saved 795 records to Tangail_historical_weather_2023_to_2025.csv
#
# Processing: Thakurgaon
# Saved 795 records to Thakurgaon_historical_weather_2023_to_2025.csv
