# %%
import pandas as pd

# %%
df = pd.read_csv('E:\BUP-ML-Portfolio\BUP-ML-Portfolio\ACC\dataset\Bagerhat_historical_weather_2023_to_2025.csv')

df.describe()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\Khalid\AppData\Local\Temp\ipykernel_21228\1763387687.py:1: SyntaxWarning: invalid escape sequence '\B'
#   df = pd.read_csv('E:\BUP-ML-Portfolio\BUP-ML-Portfolio\ACC\dataset\Bagerhat_historical_weather_2023_to_2025.csv')
#               year       month         day        temp    humidity  \
# count   795.000000  795.000000  795.000000  795.000000  795.000000
# mean   2024.000000    6.841509   15.415094   28.785660   81.416604
# std       0.817011    2.506925    8.767427    2.146245    7.582161
# min    2023.000000    3.000000    1.000000   22.200000   55.100000
# 25%    2023.000000    5.000000    8.000000   27.700000   76.800000
# 50%    2024.000000    7.000000   15.000000   29.000000   82.200000
# 75%    2025.000000    9.000000   23.000000   30.100000   86.900000
# max    2025.000000   11.000000   31.000000   34.400000   96.000000
#
# ...
